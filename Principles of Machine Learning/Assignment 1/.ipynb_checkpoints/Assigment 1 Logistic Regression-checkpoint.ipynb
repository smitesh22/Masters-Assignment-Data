# %%
import pandas as pd
train_data = pd.read_csv("plant-data/plant-train.csv")
test_data= pd.read_csv("plant-data/plant-test.csv")

# %%
from sklearn.utils import shuffle

train_data = shuffle(train_data)
test_data = shuffle(test_data)

# %%
train_data['sepal length in cm']
# Out:
# 37    4.4
# 66    6.2
# 23    5.2
# 34    5.1
# 50    6.5
#      ...
# 49    7.2
# 12    5.1
# 16    5.1
# 15    5.4
# 51    6.4
# Name: sepal length in cm, Length: 80, dtype: float64

# %%
import matplotlib.pyplot as plt
colors = {'virginica':"red", "setosa":"blue"}

plt.scatter(
    train_data['sepal length in cm'],
    train_data['sepal width in cm'],
    color = train_data['target/label'].map(colors),
)
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width in cm')
# Out:
# Text(0, 0.5, 'sepal width in cm')

# %%
import matplotlib.pyplot as plt
colors = {'virginica':"red", "setosa":"blue"}

plt.scatter(
    train_data['petal length in cm'],
    train_data['petal width in cm'],
    color = train_data['target/label'].map(colors),
)
plt.xlabel('petal length in cm')
plt.ylabel('petal width in cm')
# Out:
# Text(0, 0.5, 'petal width in cm')

# %%
import matplotlib.pyplot as plt
colors = {'virginica':"red", "setosa":"blue"}

plt.scatter(
    train_data['sepal length in cm'],
    train_data['petal width in cm'],
    color = train_data['target/label'].map(colors),
)
plt.xlabel('sepal length in cm')
plt.ylabel('petal width in cm')
# Out:
# Text(0, 0.5, 'petal width in cm')

# %%
import matplotlib.pyplot as plt
colors = {'virginica':"red", "setosa":"blue"}

plt.scatter(
    train_data['sepal width in cm'],
    train_data['petal length in cm'],
    color = train_data['target/label'].map(colors),
)
plt.xlabel('sepal width in cm')
plt.ylabel('petal length in cm')
# Out:
# Text(0, 0.5, 'petal length in cm')

# %%
train_data.head()
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 37                 4.4                3.2                 1.3
# 66                 6.2                2.8                 4.8
# 23                 5.2                3.4                 1.4
# 34                 5.1                3.4                 1.5
# 50                 6.5                3.2                 5.1
#
#     petal width in cm target/label
# 37                0.2       setosa
# 66                1.8    virginica
# 23                0.2       setosa
# 34                0.2       setosa
# 50                2.0    virginica

# %%
test_data.head()
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 19                 5.9                3.0                 5.1
# 5                  4.8                3.0                 1.4
# 17                 6.5                3.0                 5.2
# 2                  4.8                3.4                 1.6
# 16                 6.3                2.5                 5.0
#
#     petal width in cm target/label
# 19                1.8    virginica
# 5                 0.3       setosa
# 17                2.0    virginica
# 2                 0.2       setosa
# 16                1.9    virginica

# %%
X_train = train_data.drop("target/label", axis = 1)
Y_train = train_data["target/label"]
x_test = test_data.drop("target/label", axis = 1)
y_test = test_data["target/label"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix


confusion_matrix(y_test, y_pred)
# Out:
# array([[10,  0],
#        [ 0, 10]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
import numpy as np
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
x = np.linspace(-10, 10, 1000)
y = sigmoid(x)

import matplotlib.pyplot as plt
plt.plot(x, y)
plt.show()

# %%
Y_train_pred = lr.predict(X_train)

# %%
accuracy_score(Y_train_pred, Y_train)
# Out:
# 1.0

# %%
test_data= pd.read_csv("plant-data/plant-test.csv")
x_test = test_data.drop("target/label", axis = 1)
x_test['sepal length in cm']
# Out:
# 0     4.9
# 1     5.4
# 2     4.8
# 3     4.8
# 4     4.3
# 5     4.8
# 6     5.1
# 7     4.6
# 8     5.3
# 9     5.0
# 10    6.7
# 11    6.9
# 12    5.8
# 13    6.8
# 14    6.7
# 15    6.7
# 16    6.3
# 17    6.5
# 18    6.2
# 19    5.9
# Name: sepal length in cm, dtype: float64

# %%
test_data
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  4.9                3.1                 1.5
# 1                  5.4                3.7                 1.5
# 2                  4.8                3.4                 1.6
# 3                  4.8                3.0                 1.4
# 4                  4.3                3.0                 1.1
# 5                  4.8                3.0                 1.4
# 6                  5.1                3.8                 1.6
# 7                  4.6                3.2                 1.4
# 8                  5.3                3.7                 1.5
# 9                  5.0                3.3                 1.4
# 10                 6.7                3.1                 5.6
# 11                 6.9                3.1                 5.1
# 12                 5.8                2.7                 5.1
# 13                 6.8                3.2                 5.9
# ...

# %%
plt.scatter(x_test["sepal length in cm"], y_pred)
plt.xlabel("Credit Balance")
plt.ylabel("Probability of Default")
plt.show()

# %%
from sklearn.metrics import plot_precision_recall_curve

plot_roc_curve(y_test,y_pred, title="Digits ROC Curve")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8dc594570e02> in <module>
#       1 from sklearn.metrics import plot_roc_curve
#       2
# ----> 3 plot_roc_curve(y_test,y_pred, title="Digits ROC Curve")
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# TypeError: plot_roc_curve() missing 1 required positional argument: 'y'
